# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/kaggle/input/the-boston-houseprice-data/boston.csv')

# %%
data.head()

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
data.isnull().sum()

# %%
data.duplicated().sum()

# %%
plt.figure(figsize=(10,8))
data.boxplot(grid=False)
plt.title('Box Plots of attributes');

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=True,linewidths=0.5)
plt.title('Correlation between Attributes');

# %%
cols = ['CRIM','ZN','INDUS','RM','DIS','TAX','PTRATIO','B','LSTAT','MEDV']

fig,axes = plt.subplots(nrows=2,ncols=5,figsize=(12,8))

axes = axes.flatten()

colors = ['blue','green','orange','black','cyan','red','purple','magenta','pink','brown']

for i,j in enumerate(cols):
    
    data[j].plot(kind='hist',color=colors[i],ax=axes[i],rwidth=0.30)
    
    axes[i].set_title(j)

plt.suptitle('Distribution of attributes',fontsize=16)
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()

# %%
data['CHAS'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('DIstribution of CHAS');

# %%
X = data.drop(['MEDV'],axis=1).values
y = data['MEDV'].values

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=24)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(64,input_shape=(X_train.shape[1],),activation='relu'),
    Dense(32,activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mae'])
model.summary()

# %%
history = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100)

# %%
mae,loss = model.evaluate(X_test,y_test)

print(f'MAE: {mae}')
print(f'Loss: {loss}')

# %%
from sklearn.metrics import r2_score

r2_score(y_pred=model.predict(X_test),y_true=y_test)
